# %%
import sys 
print(sys.executable)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/prj_airbnb/bin/python

# %%
# !conda install --yes --prefix {sys.prefix} pandas
# Out:
# Channels:
#  - defaults
# Platform: osx-arm64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/homebrew/Caskroom/miniconda/base/envs/prj_airbnb
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |         openblas          10 KB
#     bottleneck-1.4.2           |  py312ha86b861_0         124 KB
#     libgfortran-5.0.0          |11_3_0_hca03da5_28         142 KB
#     libgfortran5-11.3.0        |      h009349e_28         1.0 MB
#     libopenblas-0.3.21         |       h269037a_0         3.3 MB
#     numexpr-2.10.1             |  py312h5d9532f_0         181 KB
#     numpy-2.0.1                |  py312h7f4fdc5_1          12 KB
#     numpy-base-2.0.1           |  py312he047099_1         6.6 MB
#     pandas-2.2.3               |  py312hcf29cfe_0        14.6 MB
# ...
