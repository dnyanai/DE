# %%
# !conda install -c conda-forge pyspark -y
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# doneecting package metadata (repodata.json): -
# doneing environment: -
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.1.0
#     latest version: 25.1.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/homebrew/Caskroom/miniconda/base/envs/prj_drugdeaths
#
#   added / updated specs:
#     - pyspark
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     arrow-cpp-19.0.0           |       h0b7d223_0         8.3 MB
#     aws-c-auth-0.6.21          |       h284e69b_0          79 KB  conda-forge
#     aws-c-cal-0.5.20           |       h7a1267a_3          29 KB  conda-forge
#     aws-c-common-0.8.5         |       h1a8c8d9_0         176 KB  conda-forge
# ...

# %%
# !conda update -n base -c defaults conda -y
# Out:
# Channels:
#  - defaults
# Platform: osx-arm64
# doneng package metadata (repodata.json):
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/homebrew/Caskroom/miniconda/base
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-25.1.1               |  py312hca03da5_0         1.2 MB
#     ------------------------------------------------------------
#                                            Total:         1.2 MB
#
# The following packages will be UPDATED:
#
#   certifi                        2024.12.14-py312hca03da5_0 --> 2025.1.31-py312hca03da5_0
#   conda                              25.1.0-py312hca03da5_0 --> 25.1.1-py312hca03da5_0
#
#
#
# ...
#
# donearing transaction: -
# donefying transaction: |
# Executing transacdone

# %%
# !conda env export > prj_env.yml

# %%
## Installed all the libraries for pyspark above
